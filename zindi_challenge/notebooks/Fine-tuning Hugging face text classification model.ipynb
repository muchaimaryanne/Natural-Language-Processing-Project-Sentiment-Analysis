# %% [markdown]
# # Sentiment Analysis with Hugging Face

# %% [markdown]
# Hugging Face is an open-source and platform provider of machine learning technologies. You can use install their package to access some interesting pre-built models to use them directly or to fine-tune (retrain it on your dataset leveraging the prior knowledge coming with the first training), then host your trained models on the platform, so that you may use them later on other devices and apps.
#
# Please, [go to the website and sign-in](https://huggingface.co/) to access all the features of the platform.
#
# [Read more about Text classification with Hugging Face](https://huggingface.co/tasks/text-classification)
#
# The Hugging face models are Deep Learning based, so will need a lot of computational GPU power to train them. Please use [Colab](https://colab.research.google.com/) to do it, or your other GPU cloud provider, or a local machine having NVIDIA GPU.

# %% [markdown]
# ## Application of Hugging Face Text classification model Fune-tuning

# %% [markdown]
# Find below a simple example, with just `3 epochs of fine-tuning`.
#
# Read more about the fine-tuning concept : [here](https://deeplizard.com/learn/video/5T-iXNNiwIs#:~:text=Fine%2Dtuning%20is%20a%20way,perform%20a%20second%20similar%20task.)

# %%
# !git clone https://github.com/muchaimaryanne/Natural-Language-Processing-Project-Sentiment-Analysis.git
# Out:
# Cloning into 'Natural-Language-Processing-Project-Sentiment-Analysis'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 5), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (27/27), 857.20 KiB | 1.72 MiB/s, done.

# %%
# %cd Natural-Language-Processing-Project-Sentiment-Analysis
# Out:
# /content/Natural-Language-Processing-Project-Sentiment-Analysis

# %%
# !pip install -r requirements.txt
# !pip install torch==1.9.0+cu111 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (0.40.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (67.6.1)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1.tar.gz (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 11.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (0.12.2)
# Requirement already satisfied: fastai in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (2.7.12)
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 104.5 MB/s eta 0:00:00
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.9-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (3.8.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (3.5.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 13)) (4.3.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (5.13.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 15)) (6.4.8)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (7.7.1)
# Collecting gradio
#   Downloading gradio-3.27.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 94.5 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 5)) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn->-r requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (1.5.29)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (0.0.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (8.4.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (23.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (2.27.1)
# Requirement already satisfied: torch<2.1,>=1.7 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (2.0.0+cu118)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (1.0.3)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from fastai->-r requirements.txt (line 8)) (0.15.1+cu118)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 9)) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 9)) (4.65.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers->-r requirements.txt (line 9)) (3.11.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.1 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 57.7 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting streamlit
#   Downloading streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 122.5 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.3 MB/s eta 0:00:00
# Collecting wandb>=0.10.32
#   Downloading wandb-0.15.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from simpletransformers->-r requirements.txt (line 10)) (2.12.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->-r requirements.txt (line 11)) (8.1.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (6.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (2.4.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (8.1.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (1.10.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy->-r requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->-r requirements.txt (line 14)) (8.2.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (5.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (5.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (0.17.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (6.1.12)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (6.5.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (5.8.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (5.5.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (6.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook->-r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->-r requirements.txt (line 16)) (6.1.0)
# Collecting qtconsole
#   Downloading qtconsole-5.4.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirements.txt (line 17)) (3.0.7)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirements.txt (line 17)) (7.34.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r requirements.txt (line 17)) (3.6.4)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 238.9 kB/s eta 0:00:00
# Collecting gradio-client>=0.1.3
#   Downloading gradio_client-0.1.3-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.2/286.2 kB 39.7 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.10-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio->-r requirements.txt (line 18)) (2.2.0)
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.7 MB/s eta 0:00:00
# Collecting websockets>=10.0
#   Downloading websockets-11.0.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 21.3 MB/s eta 0:00:00
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio->-r requirements.txt (line 18)) (2.1.2)
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 9.5 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio->-r requirements.txt (line 18)) (4.2.2)
# Collecting fastapi
#   Downloading fastapi-0.95.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio->-r requirements.txt (line 18)) (4.5.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 81.7 MB/s eta 0:00:00
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 18)) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 18)) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 18)) (0.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio-client>=0.1.3->gradio->-r requirements.txt (line 18)) (2023.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (4.4.2)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook->-r requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio->-r requirements.txt (line 18)) (0.1.2)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fastai->-r requirements.txt (line 8)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->fastai->-r requirements.txt (line 8)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fastai->-r requirements.txt (line 8)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fastai->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 12)) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 12)) (0.7.9)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (16.0.1)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers->-r requirements.txt (line 10)) (3.20.3)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers->-r requirements.txt (line 10)) (1.4.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers->-r requirements.txt (line 10)) (5.9.5)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.20.0-py2.py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 32.1 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 28.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 25.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 35.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->-r requirements.txt (line 15)) (21.2.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers->-r requirements.txt (line 10)) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 32.7 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 17.7 MB/s eta 0:00:00
# Collecting starlette<0.27.0,>=0.26.1
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio->-r requirements.txt (line 18)) (1.3.0)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (6.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (0.7.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (4.11.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook->-r requirements.txt (line 15)) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook->-r requirements.txt (line 15)) (2.16.3)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers->-r requirements.txt (line 10)) (13.3.4)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers->-r requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers->-r requirements.txt (line 10)) (4.3)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 116.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers->-r requirements.txt (line 10)) (6.4.1)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 25.9 MB/s eta 0:00:00
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers->-r requirements.txt (line 10)) (5.3.0)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.8 MB/s eta 0:00:00
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (3.4.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (2.17.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (1.53.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers->-r requirements.txt (line 10)) (1.0.0)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.4 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers->-r requirements.txt (line 10)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers->-r requirements.txt (line 10)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio->-r requirements.txt (line 18)) (3.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers->-r requirements.txt (line 10)) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r requirements.txt (line 18)) (0.19.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->-r requirements.txt (line 17)) (0.2.6)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers->-r requirements.txt (line 10)) (0.1.0.post0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 15)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook->-r requirements.txt (line 15)) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch<2.1,>=1.7->fastai->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 15)) (2.21)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers->-r requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers->-r requirements.txt (line 10)) (3.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers->-r requirements.txt (line 10)) (2023.3)
# Building wheels for collected packages: backports.zoneinfo, ffmpy, seqeval, validators, pathtools
#   Building wheel for backports.zoneinfo (pyproject.toml) ... done
#   Created wheel for backports.zoneinfo: filename=backports.zoneinfo-0.2.1-cp39-cp39-linux_x86_64.whl size=79579 sha256=12c715d904623515419bd147bbe47337fe9040ed007f5f66f9e5aace96b4a371
#   Stored in directory: /root/.cache/pip/wheels/f6/da/c4/7ac0330c0d9763cbd549898f8815e8cbc01a5bd31a009be764
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4707 sha256=6c4afdca02ed11cb1f3680f7193b0196df44350966c809003b49d29518ecadfc
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=62ae1f831069dcf85cf338967dca2bcf7de52f25d27f43719584613a6b531843
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=c2d64092b7dc3132d63df5c68d5bda7bdc0e87f2c16b17950c0de909e011864c
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=5e9ee33a2d82ab438efdffeec9b27fb583661d476a37e7d6a9f9e5cfc19113a3
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built backports.zoneinfo ffmpy seqeval validators pathtools
# Installing collected packages: tokenizers, sentencepiece, pydub, pathtools, ffmpy, xxhash, websockets, watchdog, validators, uc-micro-py, smmap, setproctitle, sentry-sdk, semantic-version, qtpy, python-multipart, pympler, orjson, multidict, jedi, h11, frozenlist, docker-pycreds, dill, blinker, backports.zoneinfo, async-timeout, aiofiles, yarl, uvicorn, starlette, responses, pydeck, multiprocess, mdit-py-plugins, linkify-it-py, huggingface-hub, httpcore, gitdb, aiosignal, transformers, seqeval, httpx, GitPython, fastapi, aiohttp, wandb, streamlit, qtconsole, gradio-client, gradio, datasets, simpletransformers, jupyter
# Successfully installed GitPython-3.1.31 aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 backports.zoneinfo-0.2.1 blinker-1.6.2 datasets-2.11.0 dill-0.3.6 docker-pycreds-0.4.0 fastapi-0.95.1 ffmpy-0.3.0 frozenlist-1.3.3 gitdb-4.0.10 gradio-3.27.0 gradio-client-0.1.3 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 huggingface-hub-0.13.4 jedi-0.18.2 jupyter-1.0.0 linkify-it-py-2.0.0 mdit-py-plugins-0.3.3 multidict-6.0.4 multiprocess-0.70.14 orjson-3.8.10 pathtools-0.1.2 pydeck-0.8.1b0 pydub-0.25.1 pympler-1.0.1 python-multipart-0.0.6 qtconsole-5.4.2 qtpy-2.3.1 responses-0.18.0 semantic-version-2.10.0 sentencepiece-0.1.98 sentry-sdk-1.20.0 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.9 smmap-5.0.0 starlette-0.26.1 streamlit-1.21.0 tokenizers-0.13.3 transformers-4.28.1 uc-micro-py-1.0.1 uvicorn-0.21.1 validators-0.20.0 wandb-0.15.0 watchdog-3.0.0 websockets-11.0.2 xxhash-3.2.0 yarl-1.9.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# Collecting torch==1.9.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.9.0%2Bcu111-cp39-cp39-linux_x86_64.whl (2041.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 861.0 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.9.0+cu111) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.9.0+cu111 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.9.0+cu111 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.9.0+cu111 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.9.0+cu111 which is incompatible.
# Successfully installed torch-1.9.0+cu111

# %%
import os
import pandas as pd
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from transformers import RobertaTokenizerFast, RobertaForSequenceClassification,Trainer, TrainingArguments
import numpy as np
from datasets import load_metric
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ca4e8fd23b32> in <cell line: 3>()
#       1 import os
#       2 import pandas as pd
# ----> 3 from datasets import load_dataset
#       4 from sklearn.model_selection import train_test_split
#       5 from transformers import RobertaTokenizerFast, RobertaForSequenceClassification,Trainer, TrainingArguments
#
# ModuleNotFoundError: No module named 'datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Disabe W&B
os.environ["WANDB_DISABLED"] = "true"
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
# Load the dataset and display some values
df = pd.read_csv('/content/Natural-Language-Processing-Project-Sentiment-Analysis/zindi_challenge/data/Train.csv')

# A way to eliminate rows containing NaN values
df = df[~df.isna().any(axis=1)]

# %% [markdown]
# I manually split the training set to have a training subset ( a dataset the model will learn on), and an evaluation subset ( a dataset the model with use to compute metric scores to help use to avoid some training problems like [the overfitting](https://www.ibm.com/cloud/learn/overfitting) one ).
#
# There are multiple ways to do split the dataset. You'll see two commented line showing you another one.

# %%
# Split the train data => {train, eval}
train, eval = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

# %%
train.head()
# Out:
#       tweet_id                                          safe_text  label  \
# 9305  YMRMEDME      Mickey's Measles has gone international <url>    0.0
# 3907  5GV8NEZS  S1256 [NEW] Extends exemption from charitable ...    0.0
# 795   EI10PS46  <user>  your ignorance on vaccines isn't just ...    1.0
# 5793  OM26E6DG  Pakistan partly suspends polio vaccination pro...    0.0
# 3431  NBBY86FX           In other news I've gone up like 1000 mmr    0.0
#
#       agreement
# 9305   1.000000
# 3907   1.000000
# 795    0.666667
# 5793   1.000000
# 3431   1.000000

# %%
eval.head()
# Out:
#       tweet_id                                          safe_text  label  \
# 6571  R7JPIFN7  Children's Museum of Houston to Offer Free Vac...    1.0
# 1754  2DD250VN  <user> no. I was properly immunized prior to t...    1.0
# 3325  ESEVBTFN  <user> thx for posting vaccinations are impera...    1.0
# 1485  S17ZU0LC  This Baby Is Exactly Why Everyone Needs To Vac...    1.0
# 4175  IIN5D33V  Meeting tonight, 8:30pm in room 322 of the stu...    1.0
#
#       agreement
# 6571   1.000000
# 1754   1.000000
# 3325   1.000000
# 1485   0.666667
# 4175   1.000000

# %%
print(f"new dataframe shapes: train is {train.shape}, eval is {eval.shape}")
# Out:
# new dataframe shapes: train is (7999, 4), eval is (2000, 4)

# %%
# Save splitted subsets
train.to_csv("/content/Natural-Language-Processing-Project-Sentiment-Analysis/zindi_challenge/data/train_subset.csv", index=False)
eval.to_csv("/content/Natural-Language-Processing-Project-Sentiment-Analysis/zindi_challenge/data/eval_subset.csv", index=False)

# %%
dataset = load_dataset('csv',
                        data_files={'train': '/content/Natural-Language-Processing-Project-Sentiment-Analysis/zindi_challenge/data/train_subset.csv',
                        'eval': '/content/Natural-Language-Processing-Project-Sentiment-Analysis/zindi_challenge/data/eval_subset.csv'}, encoding = "ISO-8859-1")
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-a1b5b46217dfdac4/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-a1b5b46217dfdac4/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
tokenizer = RobertaTokenizerFast.from_pretrained('roberta-base', max_length = 512)
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
def transform_labels(label):

    label = label['label']
    num = 0
    if label == -1: #'Negative'
        num = 0
    elif label == 0: #'Neutral'
        num = 1
    elif label == 1: #'Positive'
        num = 2

    return {'labels': num}

def tokenize_data(example):
    return tokenizer(example['safe_text'], padding='max_length')

# Change the tweets to tokens that the models can exploit
dataset = dataset.map(tokenize_data, batched=True)

# Transform	labels and remove the useless columns
remove_columns = ['tweet_id', 'label', 'safe_text', 'agreement']
dataset = dataset.map(transform_labels, remove_columns=remove_columns)
# Out:
# Map:   0%|          | 0/7999 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7999 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 7999
#     })
#     eval: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 2000
#     })
# })

# %%
# dataset['train']

# %%
from transformers import TrainingArguments

# Configure the trianing parameters like `num_train_epochs`: 
# the number of time the model will repeat the training loop over the dataset
training_args = TrainingArguments("test_trainer", evaluation_strategy='steps', num_train_epochs=10, load_best_model_at_end=True,)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
# Loading a pretrain model while specifying the number of labels in our dataset for fine-tuning
model = RobertaForSequenceClassification.from_pretrained('roberta-base',num_labels=3)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_dataset = dataset['train'].shuffle(seed=10) #.select(range(40000)) # to select a part
eval_dataset = dataset['eval'].shuffle(seed=10)

## other way to split the train set ... in the range you must use: 
# # int(num_rows*.8 ) for [0 - 80%] and  int(num_rows*.8 ),num_rows for the 20% ([80 - 100%])
# train_dataset = dataset['train'].shuffle(seed=10).select(range(40000))
# eval_dataset = dataset['train'].shuffle(seed=10).select(range(40000, 41000))

# %%
from transformers import Trainer

trainer = Trainer(
    model=model, args=training_args, train_dataset=train_dataset, eval_dataset=eval_dataset
)

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-11-1_11.1.105-1_amd64.deb
# !dpkg -i cuda-11-1_11.1.105-1_amd64.deb
# !apt-get update
# !apt-get install cuda
# Out:
# --2023-04-22 13:58:43--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-11-1_11.1.105-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-04-22 13:58:44 ERROR 404: Not Found.
#
# dpkg: error: cannot access archive 'cuda-11-1_11.1.105-1_amd64.deb': No such file or directory
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [993 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,629 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,111 kB]
# Hit:14 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,033 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,329 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,277 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [31.2 kB]
# Fetched 11.7 MB in 3s (3,482 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   accountsservice acl apg apport apport-symptoms aptdaemon aptdaemon-data
#   aspell aspell-en at-spi2-core avahi-daemon avahi-utils bind9-host bind9-libs
#   bluez bolt bubblewrap cheese-common colord colord-data cracklib-runtime crda
#   cuda-12-1 cuda-cccl-12-1 cuda-command-line-tools-12-1 cuda-compiler-12-1
#   cuda-cudart-12-1 cuda-cudart-dev-12-1 cuda-cuobjdump-12-1 cuda-cupti-12-1
#   cuda-cupti-dev-12-1 cuda-cuxxfilt-12-1 cuda-demo-suite-12-1
#   cuda-documentation-12-1 cuda-driver-dev-12-1 cuda-drivers cuda-drivers-530
#   cuda-gdb-12-1 cuda-libraries-12-1 cuda-libraries-dev-12-1 cuda-nsight-12-1
#   cuda-nsight-compute-12-1 cuda-nsight-systems-12-1 cuda-nvcc-12-1
#   cuda-nvdisasm-12-1 cuda-nvml-dev-12-1 cuda-nvprof-12-1 cuda-nvprune-12-1
#   cuda-nvrtc-12-1 cuda-nvrtc-dev-12-1 cuda-nvtx-12-1 cuda-nvvp-12-1
#   cuda-opencl-12-1 cuda-opencl-dev-12-1 cuda-profiler-api-12-1
#   cuda-runtime-12-1 cuda-sanitizer-12-1 cuda-toolkit-12-1
#   cuda-toolkit-12-1-config-common cuda-toolkit-12-config-common
#   cuda-tools-12-1 cuda-visual-tools-12-1 cups-pk-helper dbus-x11 dconf-cli
#   dctrl-tools default-jre default-jre-headless desktop-file-utils
#   dictionaries-common dkms dns-root-data dnsmasq-base docbook-xml
#   emacsen-common enchant-2 evolution-data-server evolution-data-server-common
#   fakeroot fonts-dejavu-core fonts-dejavu-extra fprintd gcr gdm3
#   gds-tools-12-1 geoclue-2.0 gettext-base gir1.2-accountsservice-1.0
#   gir1.2-atk-1.0 gir1.2-atspi-2.0 gir1.2-freedesktop gir1.2-gck-1 gir1.2-gcr-3
#   gir1.2-gdesktopenums-3.0 gir1.2-gdkpixbuf-2.0 gir1.2-gdm-1.0
#   gir1.2-geoclue-2.0 gir1.2-gnomebluetooth-1.0 gir1.2-gnomedesktop-3.0
#   gir1.2-graphene-1.0 gir1.2-gtk-3.0 gir1.2-gweather-3.0 gir1.2-ibus-1.0
#   gir1.2-json-1.0 gir1.2-mutter-6 gir1.2-nm-1.0 gir1.2-nma-1.0
#   gir1.2-notify-0.7 gir1.2-pango-1.0 gir1.2-polkit-1.0 gir1.2-rsvg-2.0
#   gir1.2-secret-1 gir1.2-soup-2.4 gir1.2-upowerglib-1.0 gir1.2-vte-2.91 gjs
#   gkbd-capplet gnome-control-center gnome-control-center-data
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring
#   gnome-keyring-pkcs11 gnome-menus gnome-online-accounts gnome-session-bin
#   gnome-session-common gnome-settings-daemon gnome-settings-daemon-common
#   gnome-shell gnome-shell-common gnome-startup-applications gnome-user-docs
#   gstreamer1.0-clutter-3.0 gstreamer1.0-gl gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x
#   hunspell-en-us ibus ibus-data ibus-gtk ibus-gtk3 iio-sensor-proxy im-config
#   ippusbxd iptables iw keyboard-configuration language-selector-common
#   language-selector-gnome libaa1 libaccountsservice0 libappindicator3-1
#   libasound2-plugins libaspell15 libatk-wrapper-java libatk-wrapper-java-jni
#   libavahi-core7 libavahi-glib1 libbluetooth3 libcamel-1.2-62
#   libcanberra-gtk3-0 libcanberra-gtk3-module libcanberra-pulse libcdparanoia0
#   libcheese-gtk25 libcheese8 libclutter-1.0-0 libclutter-1.0-common
#   libclutter-gst-3.0-0 libclutter-gtk-1.0-0 libcogl-common libcogl-pango20
#   libcogl-path20 libcogl20 libcolord-gtk1 libcolorhug2 libcrack2
#   libcublas-12-1 libcublas-dev-12-1 libcufft-12-1 libcufft-dev-12-1
#   libcufile-12-1 libcufile-dev-12-1 libcurand-12-1 libcurand-dev-12-1
#   libcusolver-12-1 libcusolver-dev-12-1 libcusparse-12-1 libcusparse-dev-12-1
#   libdaemon0 libdbusmenu-glib4 libdbusmenu-gtk3-4 libdv4 libebackend-1.2-10
#   libebook-1.2-20 libebook-contacts-1.2-3 libecal-2.0-1 libedata-book-1.2-26
#   libedata-cal-2.0-1 libedataserver-1.2-24 libedataserverui-1.2-2
#   libenchant-2-2 libfakeroot libfontenc1 libfprint-2-2 libgail-common
#   libgail18 libgck-1-0 libgcr-base-3-1 libgcr-ui-3-1 libgdata-common
#   libgdata22 libgdm1 libgee-0.8-2 libgeoclue-2-0 libgeocode-glib0 libgjs0g
#   libgnome-autoar-0-0 libgnome-bluetooth13 libgnome-desktop-3-19
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common
#   libgoa-backend-1.0-1 libgraphene-1.0-0 libgsound0 libgssdp-1.2-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-good1.0-0 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgupnp-1.2-0
#   libgupnp-av-1.0-2 libgupnp-dlna-2.0-3 libgusb2 libgweather-3-16
#   libgweather-common libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0
#   libibus-1.0-5 libical3 libidn11 libieee1284-3 libimobiledevice6 libip6tc2
#   libjansson4 libjavascriptcoregtk-4.0-18 libldb2 liblocale-gettext-perl
#   libmaxminddb0 libmbim-glib4 libmbim-proxy libmediaart-2.0-0 libmm-glib0
#   libmozjs-68-0 libmutter-6-0 libndp0 libnetfilter-conntrack3 libnewt0.52
#   libnfnetlink0 libnftnl11 libnl-genl-3-200 libnm0 libnma0 libnotify4
#   libnpp-12-1 libnpp-dev-12-1 libnss-mdns libnvidia-cfg1-530
#   libnvidia-common-530 libnvidia-compute-530 libnvidia-decode-530
#   libnvidia-encode-530 libnvidia-extra-530 libnvidia-fbc1-530 libnvidia-gl-530
#   libnvjitlink-12-1 libnvjitlink-dev-12-1 libnvjpeg-12-1 libnvjpeg-dev-12-1
#   libnvvm-samples-12-1 libpam-fprintd libpam-gnome-keyring libpangoxft-1.0-0
#   libpcap0.8 libpci3 libphonenumber7 libplist3 libpulse-mainloop-glib0
#   libpulsedsp libpwquality-common libpwquality1 libqmi-glib5 libqmi-proxy
#   librygel-core-2.6-2 librygel-db-2.6-2 librygel-renderer-2.6-2
#   librygel-server-2.6-2 libsane libsane-common libsbc1 libsecret-1-0
#   libsecret-common libshout3 libsmbclient libsnapd-glib1 libsnmp-base
#   libsnmp35 libspeexdsp1 libstartup-notification0 libtag1v5 libtag1v5-vanilla
#   libtalloc2 libteamdctl0 libtevent0 libtext-iconv-perl libudev1 libudisks2-0
#   libupower-glib3 libusbmuxd6 libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvte-2.91-0 libvte-2.91-common libwbclient0 libwebkit2gtk-4.0-37
#   libwebrtc-audio-processing1 libwhoopsie-preferences0 libwhoopsie0 libwoff1
#   libxatracker2 libxcb-res0 libxcb-xv0 libxfont2 libxkbfile1 libxklavier16
#   libxtst6 libxvmc1 libxxf86dga1 libyelp0 mesa-vulkan-drivers
#   mobile-broadband-provider-info modemmanager mousetweaks mutter mutter-common
#   netbase network-manager network-manager-gnome network-manager-pptp
#   nsight-compute-2023.1.1 nsight-systems-2023.1.2 nvidia-compute-utils-530
#   nvidia-dkms-530 nvidia-driver-530 nvidia-kernel-common-530
#   nvidia-kernel-source-530 nvidia-modprobe nvidia-prime nvidia-settings
#   nvidia-utils-530 openjdk-11-jre p11-kit p11-kit-modules pci.ids
#   pinentry-gnome3 ppp pptp-linux pulseaudio pulseaudio-module-bluetooth
#   pulseaudio-utils python3-apport python3-aptdaemon
#   python3-aptdaemon.gtk3widgets python3-blinker python3-cairo
#   python3-cffi-backend python3-cryptography python3-cups python3-cupshelpers
#   python3-defer python3-distro python3-entrypoints python3-httplib2
#   python3-ibus-1.0 python3-jwt python3-keyring python3-launchpadlib
#   python3-lazr.restfulclient python3-lazr.uri python3-ldb
#   python3-macaroonbakery python3-nacl python3-oauthlib python3-problem-report
#   python3-protobuf python3-pymacaroons python3-rfc3339 python3-secretstorage
#   python3-simplejson python3-systemd python3-talloc python3-tz python3-wadllib
#   python3-xkit rtkit rygel samba-libs sane-utils screen-resolution-extra
#   session-migration sgml-base sgml-data switcheroo-control
#   system-config-printer system-config-printer-common
#   system-config-printer-udev ubuntu-docs ubuntu-session ubuntu-wallpapers
#   ubuntu-wallpapers-focal udev update-inetd upower usb-modeswitch
#   usb-modeswitch-data usb.ids usbmuxd wamerican whoopsie-preferences
#   wireless-regdb wpasupplicant x11-utils x11-xkb-utils x11-xserver-utils
#   xdg-dbus-proxy xfonts-base xfonts-encodings xfonts-utils xml-core
#   xserver-common xserver-xephyr xserver-xorg xserver-xorg-core
#   xserver-xorg-input-all xserver-xorg-input-libinput xserver-xorg-input-wacom
#   xserver-xorg-legacy xserver-xorg-video-all xserver-xorg-video-amdgpu
#   xserver-xorg-video-ati xserver-xorg-video-fbdev xserver-xorg-video-intel
#   xserver-xorg-video-nouveau xserver-xorg-video-nvidia-530
#   xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa
#   xserver-xorg-video-vmware xwayland yaru-theme-gnome-shell yelp yelp-xsl
#   zenity zenity-common
# Suggested packages:
#   apport-gtk | apport-kde aspell-doc spellutils avahi-autoipd
#   colord-sensor-argyll debtags menu docbook docbook-dsssl docbook-xsl
#   docbook-defguide evolution gnome-orca gnome-software | gnome-packagekit
#   gnome-user-share realmd libcanberra-gtk-module usbguard chrome-gnome-shell
#   gir1.2-telepathyglib-0.12 gnome-themes-standard-data gnome-backgrounds
#   gir1.2-telepathylogger-0.2 gvfs hunspell openoffice.org-hunspell
#   | openoffice.org-core ibus-clutter ibus-doc firewalld nftables
#   indicator-application libdv-bin oss-compat libenchant-2-voikko
#   libusbmuxd-tools mmdb-bin avahi-autoipd | zeroconf hplip snapd
#   snmp-mibs-downloader libvisual-0.4-plugins gstreamer1.0-libav xdg-user-dirs
#   libteam-utils isc-dhcp-client network-manager-openconnect-gnome
#   network-manager-openvpn-gnome network-manager-vpnc-gnome
#   network-manager-pptp-gnome pinentry-doc pavumeter pavucontrol paman paprefs
#   ubuntu-sounds python-blinker-doc python-cryptography-doc
#   python3-cryptography-vectors python3-crypto libkf5wallet-bin
#   python3-keyrings.alt python3-testresources python-nacl-doc
#   python-secretstorage-doc gstreamer1.0-plugins-ugly rygel-playbin
#   rygel-preferences rygel-ruih rygel-tracker tumbler unpaper sgml-base-doc
#   perlsgml w3-recs opensp libxml2-utils gnome-software python3-smbc
#   ubuntu-wallpapers-karmic ubuntu-wallpapers-lucid ubuntu-wallpapers-maverick
#   ubuntu-wallpapers-natty ubuntu-wallpapers-oneiric ubuntu-wallpapers-precise
#   ubuntu-wallpapers-quantal ubuntu-wallpapers-raring ubuntu-wallpapers-saucy
#   ubuntu-wallpapers-trusty ubuntu-wallpapers-utopic ubuntu-wallpapers-vivid
#   ubuntu-wallpapers-wily ubuntu-wallpapers-xenial ubuntu-wallpapers-yakkety
#   ubuntu-wallpapers-zesty ubuntu-wallpapers-artful ubuntu-wallpapers-bionic
#   ubuntu-wallpapers-cosmic ubuntu-wallpapers-disco ubuntu-wallpapers-eoan
#   comgt wvdial wpagui libengine-pkcs11-openssl mesa-utils nickle cairo-5c
#   xorg-docs-core debhelper xfonts-100dpi | xfonts-75dpi xfonts-scalable xinput
#   firmware-amd-graphics xserver-xorg-video-r128 xserver-xorg-video-mach64
#   firmware-misc-nonfree
# Recommended packages:
#   libnvidia-compute-530:i386 libnvidia-decode-530:i386
#   libnvidia-encode-530:i386 libnvidia-fbc1-530:i386 libnvidia-gl-530:i386
# The following NEW packages will be installed:
#   accountsservice acl apg apport apport-symptoms aptdaemon aptdaemon-data
#   aspell aspell-en at-spi2-core avahi-daemon avahi-utils bind9-host bind9-libs
#   bluez bolt bubblewrap cheese-common colord colord-data cracklib-runtime crda
#   cuda cuda-12-1 cuda-cccl-12-1 cuda-command-line-tools-12-1
#   cuda-compiler-12-1 cuda-cudart-12-1 cuda-cudart-dev-12-1 cuda-cuobjdump-12-1
#   cuda-cupti-12-1 cuda-cupti-dev-12-1 cuda-cuxxfilt-12-1 cuda-demo-suite-12-1
#   cuda-documentation-12-1 cuda-driver-dev-12-1 cuda-drivers cuda-drivers-530
#   cuda-gdb-12-1 cuda-libraries-12-1 cuda-libraries-dev-12-1 cuda-nsight-12-1
#   cuda-nsight-compute-12-1 cuda-nsight-systems-12-1 cuda-nvcc-12-1
#   cuda-nvdisasm-12-1 cuda-nvml-dev-12-1 cuda-nvprof-12-1 cuda-nvprune-12-1
#   cuda-nvrtc-12-1 cuda-nvrtc-dev-12-1 cuda-nvtx-12-1 cuda-nvvp-12-1
#   cuda-opencl-12-1 cuda-opencl-dev-12-1 cuda-profiler-api-12-1
#   cuda-runtime-12-1 cuda-sanitizer-12-1 cuda-toolkit-12-1
#   cuda-toolkit-12-1-config-common cuda-toolkit-12-config-common
#   cuda-tools-12-1 cuda-visual-tools-12-1 cups-pk-helper dbus-x11 dconf-cli
#   dctrl-tools default-jre default-jre-headless desktop-file-utils
#   dictionaries-common dkms dns-root-data dnsmasq-base docbook-xml
#   emacsen-common enchant-2 evolution-data-server evolution-data-server-common
#   fakeroot fonts-dejavu-core fonts-dejavu-extra fprintd gcr gdm3
#   gds-tools-12-1 geoclue-2.0 gettext-base gir1.2-accountsservice-1.0
#   gir1.2-atk-1.0 gir1.2-atspi-2.0 gir1.2-freedesktop gir1.2-gck-1 gir1.2-gcr-3
#   gir1.2-gdesktopenums-3.0 gir1.2-gdkpixbuf-2.0 gir1.2-gdm-1.0
#   gir1.2-geoclue-2.0 gir1.2-gnomebluetooth-1.0 gir1.2-gnomedesktop-3.0
#   gir1.2-graphene-1.0 gir1.2-gtk-3.0 gir1.2-gweather-3.0 gir1.2-ibus-1.0
#   gir1.2-json-1.0 gir1.2-mutter-6 gir1.2-nm-1.0 gir1.2-nma-1.0
#   gir1.2-notify-0.7 gir1.2-pango-1.0 gir1.2-polkit-1.0 gir1.2-rsvg-2.0
#   gir1.2-secret-1 gir1.2-soup-2.4 gir1.2-upowerglib-1.0 gir1.2-vte-2.91 gjs
#   gkbd-capplet gnome-control-center gnome-control-center-data
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring
#   gnome-keyring-pkcs11 gnome-menus gnome-online-accounts gnome-session-bin
#   gnome-session-common gnome-settings-daemon gnome-settings-daemon-common
#   gnome-shell gnome-shell-common gnome-startup-applications gnome-user-docs
#   gstreamer1.0-clutter-3.0 gstreamer1.0-gl gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x
#   hunspell-en-us ibus ibus-data ibus-gtk ibus-gtk3 iio-sensor-proxy im-config
#   ippusbxd iptables iw keyboard-configuration language-selector-common
#   language-selector-gnome libaa1 libaccountsservice0 libappindicator3-1
#   libasound2-plugins libaspell15 libatk-wrapper-java libatk-wrapper-java-jni
#   libavahi-core7 libavahi-glib1 libbluetooth3 libcamel-1.2-62
#   libcanberra-gtk3-0 libcanberra-gtk3-module libcanberra-pulse libcdparanoia0
#   libcheese-gtk25 libcheese8 libclutter-1.0-0 libclutter-1.0-common
#   libclutter-gst-3.0-0 libclutter-gtk-1.0-0 libcogl-common libcogl-pango20
#   libcogl-path20 libcogl20 libcolord-gtk1 libcolorhug2 libcrack2
#   libcublas-12-1 libcublas-dev-12-1 libcufft-12-1 libcufft-dev-12-1
#   libcufile-12-1 libcufile-dev-12-1 libcurand-12-1 libcurand-dev-12-1
#   libcusolver-12-1 libcusolver-dev-12-1 libcusparse-12-1 libcusparse-dev-12-1
#   libdaemon0 libdbusmenu-glib4 libdbusmenu-gtk3-4 libdv4 libebackend-1.2-10
#   libebook-1.2-20 libebook-contacts-1.2-3 libecal-2.0-1 libedata-book-1.2-26
#   libedata-cal-2.0-1 libedataserver-1.2-24 libedataserverui-1.2-2
#   libenchant-2-2 libfakeroot libfontenc1 libfprint-2-2 libgail-common
#   libgail18 libgck-1-0 libgcr-base-3-1 libgcr-ui-3-1 libgdata-common
#   libgdata22 libgdm1 libgee-0.8-2 libgeoclue-2-0 libgeocode-glib0 libgjs0g
#   libgnome-autoar-0-0 libgnome-bluetooth13 libgnome-desktop-3-19
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common
#   libgoa-backend-1.0-1 libgraphene-1.0-0 libgsound0 libgssdp-1.2-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-good1.0-0 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgupnp-1.2-0
#   libgupnp-av-1.0-2 libgupnp-dlna-2.0-3 libgusb2 libgweather-3-16
#   libgweather-common libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0
#   libibus-1.0-5 libical3 libidn11 libieee1284-3 libimobiledevice6 libip6tc2
#   libjansson4 libjavascriptcoregtk-4.0-18 libldb2 liblocale-gettext-perl
#   libmaxminddb0 libmbim-glib4 libmbim-proxy libmediaart-2.0-0 libmm-glib0
#   libmozjs-68-0 libmutter-6-0 libndp0 libnetfilter-conntrack3 libnewt0.52
#   libnfnetlink0 libnftnl11 libnl-genl-3-200 libnm0 libnma0 libnotify4
#   libnpp-12-1 libnpp-dev-12-1 libnss-mdns libnvidia-cfg1-530
#   libnvidia-common-530 libnvidia-compute-530 libnvidia-decode-530
#   libnvidia-encode-530 libnvidia-extra-530 libnvidia-fbc1-530 libnvidia-gl-530
#   libnvjitlink-12-1 libnvjitlink-dev-12-1 libnvjpeg-12-1 libnvjpeg-dev-12-1
#   libnvvm-samples-12-1 libpam-fprintd libpam-gnome-keyring libpangoxft-1.0-0
#   libpcap0.8 libpci3 libphonenumber7 libplist3 libpulse-mainloop-glib0
#   libpulsedsp libpwquality-common libpwquality1 libqmi-glib5 libqmi-proxy
#   librygel-core-2.6-2 librygel-db-2.6-2 librygel-renderer-2.6-2
#   librygel-server-2.6-2 libsane libsane-common libsbc1 libsecret-1-0
#   libsecret-common libshout3 libsmbclient libsnapd-glib1 libsnmp-base
#   libsnmp35 libspeexdsp1 libstartup-notification0 libtag1v5 libtag1v5-vanilla
#   libtalloc2 libteamdctl0 libtevent0 libtext-iconv-perl libudisks2-0
#   libupower-glib3 libusbmuxd6 libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvte-2.91-0 libvte-2.91-common libwbclient0 libwebkit2gtk-4.0-37
#   libwebrtc-audio-processing1 libwhoopsie-preferences0 libwhoopsie0 libwoff1
#   libxatracker2 libxcb-res0 libxcb-xv0 libxfont2 libxkbfile1 libxklavier16
#   libxtst6 libxvmc1 libxxf86dga1 libyelp0 mesa-vulkan-drivers
#   mobile-broadband-provider-info modemmanager mousetweaks mutter mutter-common
#   netbase network-manager network-manager-gnome network-manager-pptp
#   nsight-compute-2023.1.1 nsight-systems-2023.1.2 nvidia-compute-utils-530
#   nvidia-dkms-530 nvidia-driver-530 nvidia-kernel-common-530
#   nvidia-kernel-source-530 nvidia-modprobe nvidia-prime nvidia-settings
#   nvidia-utils-530 openjdk-11-jre p11-kit p11-kit-modules pci.ids
#   pinentry-gnome3 ppp pptp-linux pulseaudio pulseaudio-module-bluetooth
#   pulseaudio-utils python3-apport python3-aptdaemon
#   python3-aptdaemon.gtk3widgets python3-blinker python3-cairo
#   python3-cffi-backend python3-cryptography python3-cups python3-cupshelpers
#   python3-defer python3-distro python3-entrypoints python3-httplib2
#   python3-ibus-1.0 python3-jwt python3-keyring python3-launchpadlib
#   python3-lazr.restfulclient python3-lazr.uri python3-ldb
#   python3-macaroonbakery python3-nacl python3-oauthlib python3-problem-report
#   python3-protobuf python3-pymacaroons python3-rfc3339 python3-secretstorage
#   python3-simplejson python3-systemd python3-talloc python3-tz python3-wadllib
#   python3-xkit rtkit rygel samba-libs sane-utils screen-resolution-extra
#   session-migration sgml-base sgml-data switcheroo-control
#   system-config-printer system-config-printer-common
#   system-config-printer-udev ubuntu-docs ubuntu-session ubuntu-wallpapers
#   ubuntu-wallpapers-focal udev update-inetd upower usb-modeswitch
#   usb-modeswitch-data usb.ids usbmuxd wamerican whoopsie-preferences
#   wireless-regdb wpasupplicant x11-utils x11-xkb-utils x11-xserver-utils
#   xdg-dbus-proxy xfonts-base xfonts-encodings xfonts-utils xml-core
#   xserver-common xserver-xephyr xserver-xorg xserver-xorg-core
#   xserver-xorg-input-all xserver-xorg-input-libinput xserver-xorg-input-wacom
#   xserver-xorg-legacy xserver-xorg-video-all xserver-xorg-video-amdgpu
#   xserver-xorg-video-ati xserver-xorg-video-fbdev xserver-xorg-video-intel
#   xserver-xorg-video-nouveau xserver-xorg-video-nvidia-530
#   xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa
#   xserver-xorg-video-vmware xwayland yaru-theme-gnome-shell yelp yelp-xsl
#   zenity zenity-common
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 474 newly installed, 0 to remove and 25 not upgraded.
# Need to get 3,216 MB of archives.
# After this operation, 7,675 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-toolkit-12-config-common 12.1.105-1 [16.4 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-toolkit-12-1-config-common 12.1.105-1 [16.3 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cudart-12-1 12.1.105-1 [158 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvrtc-12-1 12.1.105-1 [16.8 MB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-opencl-12-1 12.1.105-1 [23.8 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcublas-12-1 12.1.3.1-1 [244 MB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 liblocale-gettext-perl amd64 1.07-4 [17.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 keyboard-configuration all 1.194ubuntu3 [190 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaccountsservice0 amd64 0.6.55-0ubuntu12~20.04.5 [72.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 accountsservice amd64 0.6.55-0ubuntu12~20.04.5 [61.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 language-selector-common all 0.204.2 [224 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 dctrl-tools amd64 2.24-3 [61.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dkms all 2.8.1-5ubuntu2 [66.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsane-common all 1.0.29-0ubuntu5.2 [277 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtalloc2 amd64 2.3.3-0ubuntu0.20.04.1 [29.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtevent0 amd64 0.11.0-0ubuntu0.20.04.1 [36.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwbclient0 amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [210 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnapd-glib1 amd64 1.58-0ubuntu0.20.04.0 [90.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu1.20.04.1 [40.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev1 amd64 245.4-4ubuntu3.21 [75.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu3 [263 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libasound2-plugins amd64 1.2.2-1ubuntu1 [66.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulsedsp amd64 1:13.99.1-1ubuntu3.13 [21.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 pulseaudio-utils amd64 1:13.99.1-1ubuntu3.13 [55.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 pulseaudio amd64 1:13.99.1-1ubuntu3.13 [814 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 sgml-base all 1.29.1 [12.4 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libjansson4 amd64 2.12-1build1 [28.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libldb2 amd64 2:2.4.4-0ubuntu0.20.04.2 [143 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-ldb amd64 2:2.4.4-0ubuntu0.20.04.2 [38.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-talloc amd64 2.3.3-0ubuntu0.20.04.1 [12.2 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 samba-libs amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [5,715 kB]
# Get:33 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcufft-12-1 11.0.2.54-1 [59.9 MB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcufile-12-1 1.6.1.9-1 [643 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcurand-12-1 10.3.2.106-1 [41.5 MB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcusolver-12-1 11.4.5.107-1 [76.2 MB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcusparse-12-1 12.1.0.106-1 [108 MB]
# Get:38 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsmbclient amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [59.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libnewt0.52 amd64 0.52.21-4ubuntu2 [41.1 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libtext-iconv-perl amd64 1.7-7 [13.8 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 netbase all 6.1 [13.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-cffi-backend amd64 1.14.0-1build1 [68.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-nacl amd64 1.3.0-5 [49.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pymacaroons all 0.13.0-3 [13.2 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 udev amd64 245.4-4ubuntu3.21 [1,366 kB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnpp-12-1 12.1.0.40-1 [95.2 MB]
# Get:47 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmaxminddb0 amd64 1.4.2-0ubuntu1.20.04.1 [26.2 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-libs amd64 1:9.16.1-0ubuntu2.14 [1,109 kB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvjitlink-12-1 12.1.105-1 [14.7 MB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvjpeg-12-1 12.2.0.2-1 [2,285 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-host amd64 1:9.16.1-0ubuntu2.14 [43.0 kB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-libraries-12-1 12.1.1-1 [2,598 B]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  nvidia-modprobe 530.30.02-0ubuntu1 [20.6 kB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  nvidia-settings 530.30.02-0ubuntu1 [937 kB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-drivers-530 530.30.02-1 [2,634 B]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-drivers 530.30.02-1 [2,506 B]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-runtime-12-1 12.1.1-1 [2,502 B]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cuobjdump-12-1 12.1.111-1 [173 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext-base amd64 0.19.8.1-10build1 [50.2 kB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cuxxfilt-12-1 12.1.105-1 [190 kB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cccl-12-1 12.1.109-1 [1,060 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-driver-dev-12-1 12.1.105-1 [27.8 kB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cudart-dev-12-1 12.1.105-1 [894 kB]
# Get:64 http://archive.ubuntu.com/ubuntu focal/main amd64 libip6tc2 amd64 1.8.4-3ubuntu2 [19.2 kB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvcc-12-1 12.1.105-1 [44.7 MB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/main amd64 libnfnetlink0 amd64 1.0.1-3build1 [13.8 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 libnetfilter-conntrack3 amd64 1.0.7-2 [41.4 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 libnftnl11 amd64 1.1.5-1 [57.8 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 iptables amd64 1.8.4-3ubuntu2 [390 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcap0.8 amd64 1.9.1-3 [128 kB]
# Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 pci.ids all 0.0~2020.03.20-1 [217 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpci3 amd64 1:3.6.4-1ubuntu0.20.04.1 [26.9 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal/main amd64 usb.ids all 2020.03.19-1 [176 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/main amd64 acl amd64 2.2.53-6 [37.8 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/main amd64 apg amd64 2.2.3.dfsg.1-5 [50.6 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-httplib2 all 0.14.0-1ubuntu1 [28.9 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-problem-report all 2.20.11-0ubuntu27.26 [11.1 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-entrypoints all 0.3-2ubuntu1 [5,740 B]
# Get:79 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-cryptography amd64 2.8-3ubuntu0.1 [211 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-secretstorage all 2.3.1-2ubuntu1 [12.4 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-keyring all 18.0.1-2ubuntu1 [28.7 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-lazr.uri all 1.0.3-4build1 [13.9 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-simplejson amd64 3.16.0-2ubuntu2 [50.8 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-wadllib all 1.3.3-3build1 [45.4 kB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvprune-12-1 12.1.105-1 [58.5 kB]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-compiler-12-1 12.1.1-1 [2,506 B]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-profiler-api-12-1 12.1.105-1 [18.5 kB]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvrtc-dev-12-1 12.1.105-1 [13.9 MB]
# Get:89 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-distro all 1.4.0-1 [14.6 kB]
# Get:90 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-blinker all 1.4+dfsg1-0.3ubuntu1 [13.2 kB]
# Get:91 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-jwt all 1.7.1-2ubuntu2.1 [18.0 kB]
# Get:92 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-oauthlib all 3.1.0-1ubuntu2 [84.8 kB]
# Get:93 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-opencl-dev-12-1 12.1.105-1 [70.3 kB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcublas-dev-12-1 12.1.3.1-1 [255 MB]
# Get:95 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-lazr.restfulclient all 0.14.2-2build1 [50.7 kB]
# Get:96 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-launchpadlib all 1.10.13-1 [50.0 kB]
# Get:97 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-apport all 2.20.11-0ubuntu27.26 [87.0 kB]
# Get:98 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apport all 2.20.11-0ubuntu27.26 [129 kB]
# Get:99 http://archive.ubuntu.com/ubuntu focal/main amd64 apport-symptoms all 0.23 [13.5 kB]
# Get:100 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaspell15 amd64 0.60.8-1ubuntu0.1 [328 kB]
# Get:101 http://archive.ubuntu.com/ubuntu focal/main amd64 emacsen-common all 3.0.4 [14.9 kB]
# Get:102 http://archive.ubuntu.com/ubuntu focal/main amd64 dictionaries-common all 1.28.1 [178 kB]
# Get:103 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 aspell amd64 0.60.8-1ubuntu0.1 [88.4 kB]
# Get:104 http://archive.ubuntu.com/ubuntu focal/main amd64 aspell-en all 2018.04.16-0-1 [299 kB]
# Get:105 http://archive.ubuntu.com/ubuntu focal/main amd64 at-spi2-core amd64 2.36.0-2 [48.7 kB]
# Get:106 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libavahi-core7 amd64 0.7-4ubuntu7.1 [82.0 kB]
# Get:107 http://archive.ubuntu.com/ubuntu focal/main amd64 libdaemon0 amd64 0.14-7 [13.9 kB]
# Get:108 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 avahi-daemon amd64 0.7-4ubuntu7.1 [61.0 kB]
# Get:109 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 avahi-utils amd64 0.7-4ubuntu7.1 [24.7 kB]
# Get:110 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bluez amd64 5.53-0ubuntu3.6 [982 kB]
# Get:111 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bolt amd64 0.9.1-2~ubuntu20.04.2 [143 kB]
# Get:112 http://archive.ubuntu.com/ubuntu focal/main amd64 bubblewrap amd64 0.4.0-1ubuntu4 [35.4 kB]
# Get:113 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 cheese-common all 3.34.0-1ubuntu1 [390 kB]
# Get:114 http://archive.ubuntu.com/ubuntu focal/main amd64 libgusb2 amd64 0.3.4-0.1 [22.1 kB]
# Get:115 http://archive.ubuntu.com/ubuntu focal/main amd64 libcolorhug2 amd64 1.4.4-2 [38.4 kB]
# Get:116 http://archive.ubuntu.com/ubuntu focal/main amd64 libieee1284-3 amd64 0.2.11-13build1 [21.0 kB]
# Get:117 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnmp-base all 5.8+dfsg-2ubuntu2.7 [206 kB]
# Get:118 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnmp35 amd64 5.8+dfsg-2ubuntu2.7 [978 kB]
# Get:119 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsane amd64 1.0.29-0ubuntu5.2 [2,405 kB]
# Get:120 http://archive.ubuntu.com/ubuntu focal/main amd64 colord-data all 1.4.4-2 [1,093 kB]
# Get:121 http://archive.ubuntu.com/ubuntu focal/main amd64 colord amd64 1.4.4-2 [192 kB]
# Get:122 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcufft-dev-12-1 11.0.2.54-1 [117 MB]
# Get:123 http://archive.ubuntu.com/ubuntu focal/main amd64 libcrack2 amd64 2.9.6-3.2 [28.3 kB]
# Get:124 http://archive.ubuntu.com/ubuntu focal/main amd64 cracklib-runtime amd64 2.9.6-3.2 [140 kB]
# Get:125 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnl-genl-3-200 amd64 3.4.0-1ubuntu0.1 [11.2 kB]
# Get:126 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 wireless-regdb all 2022.06.06-0ubuntu1~20.04.1 [9,872 B]
# Get:127 http://archive.ubuntu.com/ubuntu focal/main amd64 iw amd64 5.4-1 [94.0 kB]
# Get:128 http://archive.ubuntu.com/ubuntu focal/main amd64 crda amd64 3.18-1build1 [63.5 kB]
# Get:129 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-common-530 all 530.41.03-0ubuntu0.20.04.2 [9,996 B]
# Get:130 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-compute-530 amd64 530.41.03-0ubuntu0.20.04.2 [50.6 MB]
# Get:131 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-decode-530 amd64 530.41.03-0ubuntu0.20.04.2 [1,615 kB]
# Get:132 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-encode-530 amd64 530.41.03-0ubuntu0.20.04.2 [82.5 kB]
# Get:133 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-fbc1-530 amd64 530.41.03-0ubuntu0.20.04.2 [46.9 kB]
# Get:134 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-gl-530 amd64 530.41.03-0ubuntu0.20.04.2 [188 MB]
# Get:135 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcufile-dev-12-1 1.6.1.9-1 [1,568 kB]
# Get:136 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcurand-dev-12-1 10.3.2.106-1 [41.7 MB]
# Get:137 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcusolver-dev-12-1 11.4.5.107-1 [49.2 MB]
# Get:138 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libcusparse-dev-12-1 12.1.0.106-1 [112 MB]
# Get:139 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnpp-dev-12-1 12.1.0.40-1 [92.7 MB]
# Get:140 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvjitlink-dev-12-1 12.1.105-1 [11.4 MB]
# Get:141 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvjpeg-dev-12-1 12.2.0.2-1 [1,962 kB]
# Get:142 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-libraries-dev-12-1 12.1.1-1 [2,642 B]
# Get:143 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cupti-12-1 12.1.105-1 [16.6 MB]
# Get:144 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-cupti-dev-12-1 12.1.105-1 [2,553 kB]
# Get:145 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvdisasm-12-1 12.1.105-1 [49.9 MB]
# Get:146 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-gdb-12-1 12.1.105-1 [4,538 kB]
# Get:147 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvprof-12-1 12.1.105-1 [2,435 kB]
# Get:148 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nvtx-12-1 12.1.105-1 [51.4 kB]
# Get:149 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-sanitizer-12-1 12.1.105-1 [8,921 kB]
# Get:150 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-command-line-tools-12-1 12.1.1-1 [2,542 B]
# Get:151 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  nsight-compute-2023.1.1 2023.1.1.4-1 [703 MB]
# Get:152 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-compute-utils-530 amd64 530.41.03-0ubuntu0.20.04.2 [108 kB]
# Get:153 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-kernel-source-530 amd64 530.41.03-0ubuntu0.20.04.2 [43.5 MB]
# Get:154 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-kernel-common-530 amd64 530.41.03-0ubuntu0.20.04.2 [40.4 MB]
# Get:155 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-dkms-530 amd64 530.41.03-0ubuntu0.20.04.2 [28.8 kB]
# Get:156 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-extra-530 amd64 530.41.03-0ubuntu0.20.04.2 [61.9 kB]
# Get:157 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-utils-530 amd64 530.41.03-0ubuntu0.20.04.2 [357 kB]
# Get:158 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 libnvidia-cfg1-530 amd64 530.41.03-0ubuntu0.20.04.2 [92.0 kB]
# Get:159 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:160 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:161 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:162 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:163 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:164 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-xorg-core amd64 2:1.20.13-1ubuntu1~20.04.8 [1,340 kB]
# Get:165 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 xserver-xorg-video-nvidia-530 amd64 530.41.03-0ubuntu0.20.04.2 [1,496 kB]
# Get:166 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 nvidia-driver-530 amd64 530.41.03-0ubuntu0.20.04.2 [467 kB]
# Get:167 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-xkit all 0.5.0ubuntu4 [18.3 kB]
# Get:168 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libcamel-1.2-62 amd64 3.36.5-0ubuntu1 [433 kB]
# Get:169 http://archive.ubuntu.com/ubuntu focal/main amd64 libcanberra-gtk3-0 amd64 0.30-7ubuntu1 [7,928 B]
# Get:170 http://archive.ubuntu.com/ubuntu focal/main amd64 libgck-1-0 amd64 3.36.0-2build1 [75.5 kB]
# Get:171 http://archive.ubuntu.com/ubuntu focal/main amd64 libgcr-base-3-1 amd64 3.36.0-2build1 [193 kB]
# Get:172 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgoa-1.0-common all 3.36.1-0ubuntu1 [3,752 B]
# Get:173 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgoa-1.0-0b amd64 3.36.1-0ubuntu1 [63.4 kB]
# Get:174 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdata-common all 0.17.12-1 [3,392 B]
# Get:175 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdata22 amd64 0.17.12-1 [268 kB]
# Get:176 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-common all 0.20.4-0ubuntu1 [3,940 B]
# Get:177 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-1-0 amd64 0.20.4-0ubuntu1 [110 kB]
# Get:178 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 evolution-data-server-common all 3.36.5-0ubuntu1 [18.6 kB]
# Get:179 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libedataserver-1.2-24 amd64 3.36.5-0ubuntu1 [244 kB]
# Get:180 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libebackend-1.2-10 amd64 3.36.5-0ubuntu1 [103 kB]
# Get:181 http://archive.ubuntu.com/ubuntu focal/main amd64 libphonenumber7 amd64 7.1.0-5ubuntu11 [196 kB]
# Get:182 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libebook-contacts-1.2-3 amd64 3.36.5-0ubuntu1 [54.5 kB]
# Get:183 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libedata-book-1.2-26 amd64 3.36.5-0ubuntu1 [209 kB]
# Get:184 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libebook-1.2-20 amd64 3.36.5-0ubuntu1 [79.3 kB]
# Get:185 http://archive.ubuntu.com/ubuntu focal/main amd64 libical3 amd64 3.0.8-1 [276 kB]
# Get:186 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libecal-2.0-1 amd64 3.36.5-0ubuntu1 [145 kB]
# Get:187 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libedata-cal-2.0-1 amd64 3.36.5-0ubuntu1 [127 kB]
# Get:188 http://archive.ubuntu.com/ubuntu focal/main amd64 libgcr-ui-3-1 amd64 3.36.0-2build1 [127 kB]
# Get:189 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjavascriptcoregtk-4.0-18 amd64 2.38.5-0ubuntu0.20.04.1 [6,445 kB]
# Get:190 http://archive.ubuntu.com/ubuntu focal/main amd64 xdg-dbus-proxy amd64 0.1.2-1 [23.0 kB]
# Get:191 http://archive.ubuntu.com/ubuntu focal/main amd64 hunspell-en-us all 1:2018.04.16-1 [170 kB]
# Get:192 http://archive.ubuntu.com/ubuntu focal/main amd64 libhunspell-1.7-0 amd64 1.7.0-2build2 [147 kB]
# Get:193 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libenchant-2-2 amd64 2.2.8-1ubuntu0.20.04.1 [45.6 kB]
# Get:194 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.16.3-0ubuntu1.1 [163 kB]
# Get:195 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz-icu0 amd64 2.6.4-1ubuntu4.2 [5,580 B]
# Get:196 http://archive.ubuntu.com/ubuntu focal/main amd64 libhyphen0 amd64 2.8.8-7 [27.0 kB]
# Get:197 http://archive.ubuntu.com/ubuntu focal/main amd64 libwoff1 amd64 1.0.2-1build2 [42.0 kB]
# Get:198 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebkit2gtk-4.0-37 amd64 2.38.5-0ubuntu0.20.04.1 [17.5 MB]
# Get:199 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libedataserverui-1.2-2 amd64 3.36.5-0ubuntu1 [54.7 kB]
# Get:200 http://archive.ubuntu.com/ubuntu focal/main amd64 libgeocode-glib0 amd64 3.26.2-2 [43.8 kB]
# Get:201 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgweather-common all 3.36.1-1~ubuntu20.04.1 [169 kB]
# Get:202 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgweather-3-16 amd64 3.36.1-1~ubuntu20.04.1 [68.3 kB]
# Get:203 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dbus-x11 amd64 1.12.16-2ubuntu2.3 [22.6 kB]
# Get:204 http://archive.ubuntu.com/ubuntu focal/main amd64 gcr amd64 3.36.0-2build1 [63.9 kB]
# Get:205 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 p11-kit-modules amd64 0.23.20-1ubuntu0.1 [231 kB]
# Get:206 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nsight-compute-12-1 12.1.1-1 [4,056 B]
# Get:207 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  nsight-systems-2023.1.2 2023.1.2.43-32377213v0 [297 MB]
# Get:208 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 p11-kit amd64 0.23.20-1ubuntu0.1 [93.8 kB]
# Get:209 http://archive.ubuntu.com/ubuntu focal/main amd64 pinentry-gnome3 amd64 1.1.0-3build1 [38.6 kB]
# Get:210 http://archive.ubuntu.com/ubuntu focal/main amd64 gnome-keyring amd64 3.36.0-1ubuntu1 [613 kB]
# Get:211 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 evolution-data-server amd64 3.36.5-0ubuntu1 [679 kB]
# Get:212 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-accountsservice-1.0 amd64 0.6.55-0ubuntu12~20.04.5 [4,984 B]
# Get:213 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-freedesktop amd64 1.64.1-1~ubuntu20.04.1 [19.2 kB]
# Get:214 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-atspi-2.0 amd64 2.36.0-2 [15.1 kB]
# Get:215 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-gck-1 amd64 3.36.0-2build1 [10.3 kB]
# Get:216 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-atk-1.0 amd64 2.35.1-1ubuntu2 [18.2 kB]
# Get:217 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.40.0+dfsg-3ubuntu0.4 [8,272 B]
# Get:218 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoxft-1.0-0 amd64 1.44.7-2ubuntu4 [18.0 kB]
# Get:219 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-pango-1.0 amd64 1.44.7-2ubuntu4 [26.6 kB]
# Get:220 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.20-0ubuntu1.1 [196 kB]
# Get:221 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-gcr-3 amd64 3.36.0-2build1 [15.4 kB]
# Get:222 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-gdesktopenums-3.0 amd64 3.36.0-1ubuntu1 [5,484 B]
# Get:223 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdm1 amd64 3.36.3-0ubuntu0.20.04.4 [63.6 kB]
# Get:224 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gdm-1.0 amd64 3.36.3-0ubuntu0.20.04.4 [9,584 B]
# Get:225 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libavahi-glib1 amd64 0.7-4ubuntu7.1 [7,792 B]
# Get:226 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmm-glib0 amd64 1.18.6-1~ubuntu20.04.1 [203 kB]
# Get:227 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnotify4 amd64 0.7.9-1ubuntu3.20.04.2 [19.5 kB]
# Get:228 http://archive.ubuntu.com/ubuntu focal/main amd64 geoclue-2.0 amd64 2.5.6-0ubuntu1 [91.9 kB]
# Get:229 http://archive.ubuntu.com/ubuntu focal/main amd64 libgeoclue-2-0 amd64 2.5.6-0ubuntu1 [25.1 kB]
# Get:230 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nsight-systems-12-1 12.1.1-1 [3,424 B]
# Get:231 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  cuda-nsight-12-1 12.1.105-1 [119 MB]
# Get:232 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-geoclue-2.0 amd64 2.5.6-0ubuntu1 [5,892 B]
# Get:233 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgnome-bluetooth13 amd64 3.34.3-0ubuntu1 [76.6 kB]
# Get:234 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gnomebluetooth-1.0 amd64 3.34.3-0ubuntu1 [5,592 B]
# Get:235 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gnome-desktop3-data all 3.36.8-0ubuntu1 [21.7 kB]
# Get:236 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgnome-desktop-3-19 amd64 3.36.8-0ubuntu1 [115 kB]
# Get:237 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gnomedesktop-3.0 amd64 3.36.8-0ubuntu1 [8,352 B]
# Get:238 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gweather-3.0 amd64 3.36.1-1~ubuntu20.04.1 [7,356 B]
# Get:239 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libibus-1.0-5 amd64 1.5.22-2ubuntu2.1 [153 kB]
# Get:240 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.22-2ubuntu2.1 [65.9 kB]
# Get:241 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 mutter-common all 3.36.9-0ubuntu0.20.04.2 [12.9 kB]
# Get:242 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphene-1.0-0 amd64 1.10.0-1build2 [42.9 kB]
# ...
# Setting up libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Setting up cuda-nvcc-12-1 (12.1.105-1) ...
# Setting up libcublas-12-1 (12.1.3.1-1) ...
# Setting up gir1.2-gck-1:amd64 (3.36.0-2build1) ...
# Setting up libpwquality1:amd64 (1.4.2-1build1) ...
# Setting up gir1.2-secret-1:amd64 (0.20.4-0ubuntu1) ...
# Setting up libnvjpeg-dev-12-1 (12.2.0.2-1) ...
# Setting up gir1.2-gnomedesktop-3.0:amd64 (3.36.8-0ubuntu1) ...
# Setting up libcusparse-12-1 (12.1.0.106-1) ...
# Setting up python3-cryptography (2.8-3ubuntu0.1) ...
# Setting up nvidia-dkms-530 (530.41.03-0ubuntu0.20.04.2) ...
# Loading new nvidia-530.41.03 DKMS files...
# It is likely that 5.10.147+ belongs to a chroot's host
# Building for 5.4.0-147-generic
# Building for architecture x86_64
# Building initial module for 5.4.0-147-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.4.0-147-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.4.0-147-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.4.0-147-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.4.0-147-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.4.0-147-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libcufile-dev-12-1 (1.6.1.9-1) ...
# Setting up python3-ldb (2:2.4.4-0ubuntu0.20.04.2) ...
# Setting up fprintd (1.90.9-1~ubuntu20.04.1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# Setting up aspell (0.60.8-1ubuntu0.1) ...
# Setting up usbmuxd (1.1.1~git20191130.9af2b12-1) ...
# Warning: The home dir /var/lib/usbmux you specified can't be accessed: No such file or directory
# Adding system user `usbmux' (UID 110) ...
# Adding new user `usbmux' (UID 110) with group `plugdev' ...
# Not creating home directory `/var/lib/usbmux'.
# Setting up pulseaudio-module-bluetooth (1:13.99.1-1ubuntu3.13) ...
# Setting up libcufft-dev-12-1 (11.0.2.54-1) ...
# Setting up libnpp-12-1 (12.1.0.40-1) ...
# Setting up librygel-core-2.6-2:amd64 (0.38.3-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-4ubuntu4) ...
# Setting up libnvjitlink-12-1 (12.1.105-1) ...
# Setting up ibus-gtk:amd64 (1.5.22-2ubuntu2.1) ...
# Setting up libnetfilter-conntrack3:amd64 (1.0.7-2) ...
# Setting up libgtk2.0-bin (2.24.32-4ubuntu4) ...
# Setting up libnpp-dev-12-1 (12.1.0.40-1) ...
# Setting up cuda-opencl-12-1 (12.1.105-1) ...
# Setting up xml-core (0.18+nmu1) ...
# Setting up libcurand-12-1 (10.3.2.106-1) ...
# Setting up x11-utils (7.7+5) ...
# Setting up gir1.2-upowerglib-1.0:amd64 (0.99.11-1build2) ...
# Setting up hunspell-en-us (1:2018.04.16-1) ...
# Setting up language-selector-common (0.204.2) ...
# Setting up cuda-command-line-tools-12-1 (12.1.1-1) ...
# Setting up gir1.2-vte-2.91:amd64 (0.60.3-0ubuntu1~20.04) ...
# Setting up libatk-wrapper-java (0.37.1-1) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up keyboard-configuration (1.194ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up sane-utils (1.0.29-0ubuntu5.2) ...
# update-inetd: warning: cannot add service, /etc/inetd.conf does not exist
# Adding saned group and user...
# Adding user saned to group scanner
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up xwayland (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up python3-ibus-1.0 (1.5.22-2ubuntu2.1) ...
# Setting up gir1.2-gnomebluetooth-1.0:amd64 (3.34.3-0ubuntu1) ...
# Setting up bind9-host (1:9.16.1-0ubuntu2.14) ...
# Setting up xserver-xorg-legacy (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libclutter-1.0-0:amd64 (1.26.4+dfsg-1) ...
# Setting up python3-nacl (1.3.0-5) ...
# Setting up libpam-fprintd:amd64 (1.90.9-1~ubuntu20.04.1) ...
# Setting up librygel-server-2.6-2:amd64 (0.38.3-1ubuntu1) ...
# Setting up cuda-compiler-12-1 (12.1.1-1) ...
# Setting up libxklavier16:amd64 (5.4-4) ...
# Setting up libcanberra-pulse:amd64 (0.30-7ubuntu1) ...
# Setting up cuda-libraries-12-1 (12.1.1-1) ...
# Setting up system-config-printer-common (1.5.12-0ubuntu1.1) ...
# Setting up libgeoclue-2-0:amd64 (2.5.6-0ubuntu1) ...
# Setting up libclutter-gtk-1.0-0:amd64 (1.8.4-4) ...
# Setting up libnvjitlink-dev-12-1 (12.1.105-1) ...
# Setting up gir1.2-nma-1.0:amd64 (1.8.24-1ubuntu3) ...
# Setting up python3-pymacaroons (0.13.0-3) ...
# Setting up libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up libgail-common:amd64 (2.24.32-4ubuntu4) ...
# Setting up iptables (1.8.4-3ubuntu2) ...
# update-alternatives: using /usr/sbin/iptables-legacy to provide /usr/sbin/iptables (iptables) in auto mode
# update-alternatives: using /usr/sbin/ip6tables-legacy to provide /usr/sbin/ip6tables (ip6tables) in auto mode
# update-alternatives: using /usr/sbin/arptables-nft to provide /usr/sbin/arptables (arptables) in auto mode
# update-alternatives: using /usr/sbin/ebtables-nft to provide /usr/sbin/ebtables (ebtables) in auto mode
# Setting up gjs (1.64.5-0ubuntu0.20.04.01) ...
# Setting up colord (1.4.4-2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libcusparse-dev-12-1 (12.1.0.106-1) ...
# Setting up system-config-printer-udev (1.5.12-0ubuntu1.1) ...
# Setting up gnome-session-bin (3.36.0-2ubuntu1) ...
# update-alternatives: using /usr/bin/gnome-session to provide /usr/bin/x-session-manager (x-session-manager) in auto mode
# Setting up libcurand-dev-12-1 (10.3.2.106-1) ...
# Setting up xserver-xorg-core (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up aspell-en (2018.04.16-0-1) ...
# Setting up enchant-2 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up samba-libs:amd64 (2:4.15.13+dfsg-0ubuntu0.20.04.2) ...
# Setting up libqmi-glib5:amd64 (1.30.4-1~ubuntu20.04.1) ...
# Setting up network-manager (1.22.10-1ubuntu2.3) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.nm-dispatcher.service → /lib/systemd/system/NetworkManager-dispatcher.service.
# Created symlink /etc/systemd/system/network-online.target.wants/NetworkManager-wait-online.service → /lib/systemd/system/NetworkManager-wait-online.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/NetworkManager.service → /lib/systemd/system/NetworkManager.service.
# Setting up libcublas-dev-12-1 (12.1.3.1-1) ...
# Setting up xserver-xorg-video-radeon (1:19.1.0-1) ...
# Setting up dnsmasq-base (2.80-1.1ubuntu1.7) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.37.1-1) ...
# Setting up xserver-xorg-input-wacom (1:0.39.0-0ubuntu1) ...
# Setting up gir1.2-gcr-3:amd64 (3.36.0-2build1) ...
# Setting up network-manager-pptp (1.2.8-2) ...
# Setting up xserver-xorg-video-fbdev (1:0.5.0-1ubuntu1) ...
# Setting up python3-oauthlib (3.1.0-1ubuntu2) ...
# Setting up python3-secretstorage (2.3.1-2ubuntu1) ...
# Setting up system-config-printer (1.5.12-0ubuntu1.1) ...
# Setting up xserver-xephyr (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xserver-xorg-video-vmware (1:13.3.0-3) ...
# Setting up xserver-xorg-video-intel (2:2.99.917+git20200226-1) ...
# Setting up gir1.2-geoclue-2.0:amd64 (2.5.6-0ubuntu1) ...
# Setting up librygel-renderer-2.6-2:amd64 (0.38.3-1ubuntu1) ...
# Setting up librygel-db-2.6-2:amd64 (0.38.3-1ubuntu1) ...
# Setting up libsmbclient:amd64 (2:4.15.13+dfsg-0ubuntu0.20.04.2) ...
# Setting up xserver-xorg-video-nvidia-530 (530.41.03-0ubuntu0.20.04.2) ...
# Setting up cuda-opencl-dev-12-1 (12.1.105-1) ...
# Setting up avahi-daemon (0.7-4ubuntu7.1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.Avahi.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/avahi-daemon.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/sockets.target.wants/avahi-daemon.socket → /lib/systemd/system/avahi-daemon.socket.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libwebkit2gtk-4.0-37:amd64 (2.38.5-0ubuntu0.20.04.1) ...
# Setting up xserver-xorg-video-vesa (1:2.4.0-2) ...
# Setting up python3-keyring (18.0.1-2ubuntu1) ...
# Setting up python3-macaroonbakery (1.3.1-1) ...
# Setting up python3-lazr.restfulclient (0.14.2-2build1) ...
# Setting up libnss-mdns:amd64 (0.14.1-1ubuntu1) ...
# First installation detected...
# Checking NSS setup...
# Setting up libclutter-gst-3.0-0:amd64 (3.0.27-1) ...
# Setting up cuda-libraries-dev-12-1 (12.1.1-1) ...
# Setting up xserver-xorg-video-qxl (0.1.5+git20200331-1) ...
# Setting up xserver-xorg-video-amdgpu (19.1.0-1ubuntu0.1) ...
# Setting up python3-launchpadlib (1.10.13-1) ...
# Setting up xserver-xorg-video-nouveau (1:1.0.16-1) ...
# Setting up avahi-utils (0.7-4ubuntu7.1) ...
# Setting up xserver-xorg-input-libinput (0.29.0-1) ...
# Setting up xserver-xorg-video-ati (1:19.1.0-1) ...
# Setting up nvidia-driver-530 (530.41.03-0ubuntu0.20.04.2) ...
# Setting up libqmi-proxy (1.30.4-1~ubuntu20.04.1) ...
# Setting up libyelp0:amd64 (3.36.2-0ubuntu1) ...
# Setting up cuda-visual-tools-12-1 (12.1.1-1) ...
# Setting up rygel (0.38.3-1ubuntu1) ...
# Setting up zenity (3.32.0-5) ...
# Setting up python3-apport (2.20.11-0ubuntu27.26) ...
# Setting up xserver-xorg-video-all (1:7.7+19ubuntu14) ...
# Setting up gstreamer1.0-clutter-3.0:amd64 (3.0.27-1) ...
# Setting up modemmanager (1.18.6-1~ubuntu20.04.1) ...
# Created symlink /etc/systemd/system/dbus-org.freedesktop.ModemManager1.service → /lib/systemd/system/ModemManager.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/ModemManager.service → /lib/systemd/system/ModemManager.service.
# Setting up xserver-xorg-input-all (1:7.7+19ubuntu14) ...
# Setting up xserver-xorg (1:7.7+19ubuntu14) ...
# Setting up cuda-tools-12-1 (12.1.1-1) ...
# Setting up yelp (3.36.2-0ubuntu1) ...
# Setting up cuda-toolkit-12-1 (12.1.1-1) ...
# Setting up apport (2.20.11-0ubuntu27.26) ...
# Created symlink /etc/systemd/system/paths.target.wants/apport-autoreport.path → /lib/systemd/system/apport-autoreport.path.
# Created symlink /etc/systemd/system/sockets.target.wants/apport-forward.socket → /lib/systemd/system/apport-forward.socket.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up aptdaemon (1.1.1+bzr982-0ubuntu32.3) ...
# Setting up python3-aptdaemon (1.1.1+bzr982-0ubuntu32.3) ...
# Setting up python3-aptdaemon.gtk3widgets (1.1.1+bzr982-0ubuntu32.3) ...
# Setting up language-selector-gnome (0.204.2) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Processing triggers for libgtk-3-0:amd64 (3.24.20-0ubuntu1.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for systemd (245.4-4ubuntu3.21) ...
# Setting up libgweather-3-16:amd64 (3.36.1-1~ubuntu20.04.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libgnomekbd8:amd64 (3.26.1-1) ...
# Setting up pinentry-gnome3 (1.1.0-3build1) ...
# Processing triggers for dbus (1.12.16-2ubuntu2.3) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Setting up libgoa-1.0-0b:amd64 (3.36.1-0ubuntu1) ...
# Setting up ibus (1.5.22-2ubuntu2.1) ...
# Setting up gnome-startup-applications (3.36.0-2ubuntu1) ...
# Setting up libcheese8:amd64 (3.34.0-1ubuntu1) ...
# Setting up gir1.2-gdm-1.0:amd64 (3.36.3-0ubuntu0.20.04.4) ...
# Setting up libgoa-backend-1.0-1:amd64 (3.36.1-0ubuntu1) ...
# Setting up libgdata22:amd64 (0.17.12-1) ...
# Setting up libmutter-6-0:amd64 (3.36.9-0ubuntu0.20.04.2) ...
# Setting up ubuntu-docs (20.04.3) ...
# Setting up gir1.2-mutter-6:amd64 (3.36.9-0ubuntu0.20.04.2) ...
# Setting up gnome-keyring (3.36.0-1ubuntu1) ...
# Setting up gnome-online-accounts (3.36.1-0ubuntu1) ...
# Setting up gnome-settings-daemon (3.36.1-0ubuntu1.1) ...
# Setting up gnome-user-docs (3.36.2+git20200704-0ubuntu0.1) ...
# Setting up gir1.2-gweather-3.0:amd64 (3.36.1-1~ubuntu20.04.1) ...
# Setting up gkbd-capplet (3.26.1-1) ...
# Setting up mutter (3.36.9-0ubuntu0.20.04.2) ...
# update-alternatives: using /usr/bin/mutter to provide /usr/bin/x-window-manager (x-window-manager) in auto mode
# Setting up libcheese-gtk25:amd64 (3.34.0-1ubuntu1) ...
# Setting up libedataserver-1.2-24:amd64 (3.36.5-0ubuntu1) ...
# Setting up libecal-2.0-1:amd64 (3.36.5-0ubuntu1) ...
# Setting up libebook-contacts-1.2-3:amd64 (3.36.5-0ubuntu1) ...
# Setting up gnome-control-center (1:3.36.5-0ubuntu4) ...
# Setting up libedataserverui-1.2-2:amd64 (3.36.5-0ubuntu1) ...
# Setting up libebackend-1.2-10:amd64 (3.36.5-0ubuntu1) ...
# Setting up libedata-cal-2.0-1:amd64 (3.36.5-0ubuntu1) ...
# Setting up libedata-book-1.2-26:amd64 (3.36.5-0ubuntu1) ...
# Setting up libebook-1.2-20:amd64 (3.36.5-0ubuntu1) ...
# Setting up evolution-data-server (3.36.5-0ubuntu1) ...
# Setting up gnome-shell (3.36.9-0ubuntu0.20.04.2) ...
# Setting up screen-resolution-extra (0.18build1) ...
# Setting up ubuntu-session (3.36.0-2ubuntu1) ...
# Setting up gdm3 (3.36.3-0ubuntu0.20.04.4) ...
#
# Creating config file /etc/gdm3/greeter.dconf-defaults with new version
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of reload.
# Setting up nvidia-settings (530.30.02-0ubuntu1) ...
# Setting up cuda-drivers-530 (530.30.02-1) ...
# Setting up network-manager-gnome (1.8.24-1ubuntu3) ...
# Setting up cuda-drivers (530.30.02-1) ...
# Setting up cuda-runtime-12-1 (12.1.1-1) ...
# Setting up cuda-demo-suite-12-1 (12.1.105-1) ...
# Setting up cuda-12-1 (12.1.1-1) ...
# Setting up cuda (12.1.1-1) ...
# Processing triggers for sgml-base (1.29.1) ...
# Setting up sgml-data (2.0.11) ...
# Processing triggers for sgml-base (1.29.1) ...
# Setting up docbook-xml (4.5-9) ...
# Processing triggers for dictionaries-common (1.28.1) ...
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Processing triggers for rygel (0.38.3-1ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for dbus (1.12.16-2ubuntu2.3) ...
# Processing triggers for systemd (245.4-4ubuntu3.21) ...
# Processing triggers for sgml-base (1.29.1) ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:16:06_PDT_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0

# %%
# Launch the learning process: training 
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 2:38:29, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.823100</td>
#       <td>0.805450</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.713900</td>
#       <td>0.709789</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.686600</td>
#       <td>0.615619</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.628700</td>
#       <td>0.683672</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.531100</td>
#       <td>0.582671</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.533300</td>
#       <td>0.700551</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.462900</td>
#       <td>0.777262</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.452100</td>
#       <td>0.693756</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.356300</td>
#       <td>0.829306</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.358500</td>
#       <td>1.111701</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.273700</td>
#       <td>1.157661</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.291900</td>
#       <td>1.052973</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.212900</td>
#       <td>1.224642</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.212700</td>
#       <td>1.177068</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.160600</td>
#       <td>1.360687</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.160100</td>
#       <td>1.371067</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.117900</td>
#       <td>1.485962</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.107800</td>
#       <td>1.443955</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.076200</td>
#       <td>1.539215</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.089400</td>
#       <td>1.509904</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10000, training_loss=0.3624948829650879, metrics={'train_runtime': 9510.8311, 'train_samples_per_second': 8.41, 'train_steps_per_second': 1.051, 'total_flos': 2.104644228406272e+16, 'train_loss': 0.3624948829650879, 'epoch': 10.0})

# %% [markdown]
# Don't worry the above issue, it is a `KeyboardInterrupt` that means I stopped the training to avoid taking a long time to finish.

# %%
metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
# Out:
# <ipython-input-22-75db7450f822>:4: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
)

# %%
# Launch the final evaluation 
trainer.evaluate()
# Out:
# Downloading builder script: 4.21kB [00:00, 932kB/s]
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 250/250 [09:04<00:00,  2.18s/it]
# {'eval_loss': 0.6274272203445435,
#  'eval_accuracy': 0.7665,
#  'eval_runtime': 546.3013,
#  'eval_samples_per_second': 3.661,
#  'eval_steps_per_second': 0.458}

# %% [markdown]
# Some checkpoints of the model are automatically saved locally in `test_trainer/` during the training.

# %% [markdown]
# You may also upload the model on the Hugging Face Platform... [Read more](https://huggingface.co/docs/hub/models-uploading)

# %% [markdown]
# This notebook is inspired by an article: [Fine-Tuning Bert for Tweets Classification ft. Hugging Face](https://medium.com/mlearning-ai/fine-tuning-bert-for-tweets-classification-ft-hugging-face-8afebadd5dbf)

# %% [markdown]
# Do not hesitaite to read more and to ask questions, the Learning is a lifelong activity.
